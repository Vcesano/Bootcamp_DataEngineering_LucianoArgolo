-- %%
-- ejercicio 2.5 ddl
CREATE TABLE IF NOT EXISTS bootcamp_de_valentin.gold.fact_propiedades_2 (
  row_hash STRING NOT NULL,
  zona_id  BIGINT,
  caracteristicas_id  BIGINT,
  orientacion_id  BIGINT,
  tipo_operacion_id  BIGINT,
  fecha_id  BIGINT,
  precio DECIMAL(15,2),
  precio_m2 DECIMAL(15,2),
  expensas DECIMAL(15,2),
  m2_totales DECIMAL(15,2),
  m2_cubiertos DECIMAL(15,2),
  ambientes INT,
  url STRING COMMENT 'Degenerated dimension',
  _refresh_timestamp TIMESTAMP DEFAULT CURRENT_TIMESTAMP()
)
USING DELTA
TBLPROPERTIES ('delta.feature.allowColumnDefaults' = 'supported')
COMMENT 'Hechos de propiedades-- Gold -- BK: url + precio -- SK: row_hash (md5 de url + precio)'
