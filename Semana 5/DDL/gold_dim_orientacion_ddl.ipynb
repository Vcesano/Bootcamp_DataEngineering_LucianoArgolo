-- %%
-- ejercicio extra ddl
CREATE TABLE IF NOT EXISTS bootcamp_de_valentin.gold.dim_orientacion_2 (
  orientacion_id BIGINT GENERATED ALWAYS AS IDENTITY (START WITH 1 INCREMENT BY 1),
  orientacion STRING NOT NULL,
  tipo_orientacion STRING COMMENT 'derivada: norte, sur, este, oeste',
  _created_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP()
)
USING DELTA
TBLPROPERTIES ('delta.feature.allowColumnDefaults' = 'supported')
COMMENT 'Dimension de orientacion -- Gold -- BK: orientacion -- SK: orientacion_id'
