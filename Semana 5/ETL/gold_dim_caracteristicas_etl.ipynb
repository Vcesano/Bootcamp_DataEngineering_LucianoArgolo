-- %%
-- ejercicio 2.2 etl
INSERT INTO bootcamp_de_valentin.gold.dim_caracteristicas_2 (estado, cochera)
SELECT DISTINCT
  coalesce( estado, 'sin especificar' ) AS estado,
  coalesce( cochera, false ) AS cochera 
FROM bootcamp_de_valentin.silver.propiedades_silver
