-- %%
-- ejercicio 2.1 etl
INSERT INTO bootcamp_de_valentin.gold.dim_zona_2 (partido, region, ciudad)
SELECT DISTINCT
  partido,
  region,
  CASE
    WHEN partido = 'capital federal'  THEN 'CABA'
    ELSE 'GBA'
  END AS ciudad
FROM bootcamp_de_valentin.silver.propiedades_silver
WHERE
  partido IS NOT NULL
